# %% [markdown]
# Preprocessing the movement for modeling

# %%
#Importing dependencies
import pandas as pd
import os

# %%
df = pd.read_csv("/users/imbahndu/Desktop/Columbia DBM/Smartwatch dataset_In progress/preprocessed/file_list.csv")

# %%
df
# Out:
#     resource_type   id  ... effect_of_alcohol_on_tremor label
# 0         patient    1  ...                     Unknown     0
# 1         patient    2  ...                   No effect     2
# 2         patient    3  ...                     Unknown     0
# 3         patient    4  ...                   No effect     1
# 4         patient    5  ...                     Unknown     1
# ..            ...  ...  ...                         ...   ...
# 464       patient  465  ...                   No effect     1
# 465       patient  466  ...                   No effect     0
# 466       patient  467  ...                 Improvement     1
# 467       patient  468  ...                   No effect     1
# 468       patient  469  ...                     Unknown     1
#
# [469 rows x 15 columns]

# %%
print(df["condition"].value_counts())
# Out:
# condition
# Parkinson's                 276
# Healthy                      79
# Other Movement Disorders     60
# Essential Tremor             28
# Atypical Parkinsonism        15
# Multiple Sclerosis           11
# Name: count, dtype: int64

# %%
print(df.isnull().sum())
# Out:
# resource_type                          0
# id                                     0
# study_id                               0
# condition                              0
# disease_comment                        0
# age_at_diagnosis                       0
# age                                    0
# height                                 0
# weight                                 0
# gender                                 0
# handedness                             0
# appearance_in_kinship                  0
# appearance_in_first_grade_kinship    288
# effect_of_alcohol_on_tremor            0
# label                                  0
# dtype: int64

# %%
# Define column names for timeseries data as per what the paper suggested 
columns = ['Time', 'Accelerometer_X', 'Accelerometer_Y', 'Accelerometer_Z', 
           'Gyroscope_X', 'Gyroscope_Y', 'Gyroscope_Z']

def extract_features(df):
    features = {}
    sensor_cols = columns[1:]  # exclude Time column
    
    #For each column present, calculate descriptiv4 stats to reduce dimensioinality of data 
    for col in sensor_cols:
        features[f'{col}_mean'] = df[col].mean()
        features[f'{col}_std'] = df[col].std()
        features[f'{col}_max'] = df[col].max()
        features[f'{col}_min'] = df[col].min()
    
    #Return key value pairs of the feature
    return features

def load_and_extract_all(timeseries_folder):
    all_features = []
    
    #looping through each filename in the timeseries,
    for filename in os.listdir(timeseries_folder):
        if filename.endswith('.txt'):
            #looking for files wityh the timer series folder and join them together 
            filepath = os.path.join(timeseries_folder, filename)
            # Load with proper column names
            df = pd.read_csv(filepath, names=columns, sep=',')
            
            feats = extract_features(df)
            
            # Extract metadata from filename, with the format ("001_Task_LeftWrist.txt")
            #sp[lit returns a list split by _
            parts = filename.split('_')
            #parse out patient id
            patient_id = parts[0]
            #get the task name
            task = parts[1] if len(parts) > 1 else 'unknown'
            #get the wrist id as well
            wrist = parts[2].replace('.txt','') if len(parts) > 2 else 'unknown'
            #Append to the dictionary all the indices
            feats['patient_id'] = patient_id
            feats['task'] = task
            feats['wrist'] = wrist
            #Append to the list thje dictionary 
            all_features.append(feats)
    
    #return pd dataframe
    return pd.DataFrame(all_features)

#Call the funcsions and link the path to folder and load it
timeseries_folder = "/users/imbahndu/Desktop/Columbia DBM/Smartwatch dataset_In progress/movement/timeseries"
features_df = load_and_extract_all(timeseries_folder)

# %%
features_df
# Out:
#        Accelerometer_X_mean  Accelerometer_X_std  ...         task       wrist
# 0                 -0.130550             0.248221  ...    CrossArms   LeftWrist
# 1                 -0.096928             0.185871  ...    CrossArms  RightWrist
# 2                 -0.006727             0.066519  ...    DrinkGlas   LeftWrist
# 3                 -0.030242             0.162984  ...    DrinkGlas  RightWrist
# 4                 -0.000358             0.020462  ...  Entrainment   LeftWrist
# ...                     ...                  ...  ...          ...         ...
# 10313              0.002170             0.008781  ...  StretchHold  RightWrist
# 10314              0.149720             0.164865  ...   TouchIndex   LeftWrist
# 10315             -0.153192             0.116114  ...   TouchIndex  RightWrist
# 10316              0.014965             0.086383  ...    TouchNose   LeftWrist
# 10317              0.047650             0.125589  ...    TouchNose  RightWrist
#
# [10318 rows x 27 columns]

# %% [markdown]
# features_df.head(20)

# %%
features_df
# Out:
#        Accelerometer_X_mean  Accelerometer_X_std  ...         task       wrist
# 0                 -0.130550             0.248221  ...    CrossArms   LeftWrist
# 1                 -0.096928             0.185871  ...    CrossArms  RightWrist
# 2                 -0.006727             0.066519  ...    DrinkGlas   LeftWrist
# 3                 -0.030242             0.162984  ...    DrinkGlas  RightWrist
# 4                 -0.000358             0.020462  ...  Entrainment   LeftWrist
# ...                     ...                  ...  ...          ...         ...
# 10313              0.002170             0.008781  ...  StretchHold  RightWrist
# 10314              0.149720             0.164865  ...   TouchIndex   LeftWrist
# 10315             -0.153192             0.116114  ...   TouchIndex  RightWrist
# 10316              0.014965             0.086383  ...    TouchNose   LeftWrist
# 10317              0.047650             0.125589  ...    TouchNose  RightWrist
#
# [10318 rows x 27 columns]

# %%
# Convert patient IDs to same format because of shape mistmatch
features_df['patient_id'] = features_df['patient_id'].astype(int)  # from '001' → 1
#Convert the pd dataframe as well to ensure everything is okay 
df['patient_id'] = df['id'].astype(int)

df
# Out:
#     resource_type   id study_id  ... effect_of_alcohol_on_tremor label  patient_id
# 0         patient    1     PADS  ...                     Unknown     0           1
# 1         patient    2     PADS  ...                   No effect     2           2
# 2         patient    3     PADS  ...                     Unknown     0           3
# 3         patient    4     PADS  ...                   No effect     1           4
# 4         patient    5     PADS  ...                     Unknown     1           5
# ..            ...  ...      ...  ...                         ...   ...         ...
# 464       patient  465     PADS  ...                   No effect     1         465
# 465       patient  466     PADS  ...                   No effect     0         466
# 466       patient  467     PADS  ...                 Improvement     1         467
# 467       patient  468     PADS  ...                   No effect     1         468
# 468       patient  469     PADS  ...                     Unknown     1         469
#
# [469 rows x 16 columns]

# %%
features_df
# Out:
#        Accelerometer_X_mean  Accelerometer_X_std  ...         task       wrist
# 0                 -0.130550             0.248221  ...    CrossArms   LeftWrist
# 1                 -0.096928             0.185871  ...    CrossArms  RightWrist
# 2                 -0.006727             0.066519  ...    DrinkGlas   LeftWrist
# 3                 -0.030242             0.162984  ...    DrinkGlas  RightWrist
# 4                 -0.000358             0.020462  ...  Entrainment   LeftWrist
# ...                     ...                  ...  ...          ...         ...
# 10313              0.002170             0.008781  ...  StretchHold  RightWrist
# 10314              0.149720             0.164865  ...   TouchIndex   LeftWrist
# 10315             -0.153192             0.116114  ...   TouchIndex  RightWrist
# 10316              0.014965             0.086383  ...    TouchNose   LeftWrist
# 10317              0.047650             0.125589  ...    TouchNose  RightWrist
#
# [10318 rows x 27 columns]

# %%
# Merge dfs pon the basis of ids"
merged_df = pd.merge(df, features_df, on="patient_id")

# %%
merged_df
# Out:
#       resource_type   id study_id  ... Gyroscope_Z_min         task       wrist
# 0           patient    1     PADS  ...       -6.042105    CrossArms   LeftWrist
# 1           patient    1     PADS  ...       -6.602785    CrossArms  RightWrist
# 2           patient    1     PADS  ...       -1.383440    DrinkGlas   LeftWrist
# 3           patient    1     PADS  ...       -4.873748    DrinkGlas  RightWrist
# 4           patient    1     PADS  ...       -0.416381  Entrainment   LeftWrist
# ...             ...  ...      ...  ...             ...          ...         ...
# 10313       patient  469     PADS  ...       -0.060294  StretchHold  RightWrist
# 10314       patient  469     PADS  ...       -5.481484   TouchIndex   LeftWrist
# 10315       patient  469     PADS  ...       -4.422117   TouchIndex  RightWrist
# 10316       patient  469     PADS  ...       -4.469865    TouchNose   LeftWrist
# 10317       patient  469     PADS  ...       -5.108847    TouchNose  RightWrist
#
# [10318 rows x 42 columns]

# %%
#Finding null values
merged_df.isnull().sum()
# Out:
# resource_type                           0
# id                                      0
# study_id                                0
# condition                               0
# disease_comment                         0
# age_at_diagnosis                        0
# age                                     0
# height                                  0
# weight                                  0
# gender                                  0
# handedness                              0
# appearance_in_kinship                   0
# appearance_in_first_grade_kinship    6336
# effect_of_alcohol_on_tremor             0
# label                                   0
# patient_id                              0
# Accelerometer_X_mean                    0
# Accelerometer_X_std                     0
# Accelerometer_X_max                     0
# Accelerometer_X_min                     0
# Accelerometer_Y_mean                    0
# Accelerometer_Y_std                     0
# Accelerometer_Y_max                     0
# Accelerometer_Y_min                     0
# Accelerometer_Z_mean                    0
# Accelerometer_Z_std                     0
# Accelerometer_Z_max                     0
# Accelerometer_Z_min                     0
# Gyroscope_X_mean                        0
# Gyroscope_X_std                         0
# Gyroscope_X_max                         0
# Gyroscope_X_min                         0
# Gyroscope_Y_mean                        0
# Gyroscope_Y_std                         0
# Gyroscope_Y_max                         0
# Gyroscope_Y_min                         0
# Gyroscope_Z_mean                        0
# Gyroscope_Z_std                         0
# Gyroscope_Z_max                         0
# Gyroscope_Z_min                         0
# task                                    0
# wrist                                   0
# dtype: int64

# %%
#Drop the null columns 
merged_df = merged_df.drop(columns = ["appearance_in_first_grade_kinship"])

# %%
merged_df
# Out:
#       resource_type   id study_id  ... Gyroscope_Z_min         task       wrist
# 0           patient    1     PADS  ...       -6.042105    CrossArms   LeftWrist
# 1           patient    1     PADS  ...       -6.602785    CrossArms  RightWrist
# 2           patient    1     PADS  ...       -1.383440    DrinkGlas   LeftWrist
# 3           patient    1     PADS  ...       -4.873748    DrinkGlas  RightWrist
# 4           patient    1     PADS  ...       -0.416381  Entrainment   LeftWrist
# ...             ...  ...      ...  ...             ...          ...         ...
# 10313       patient  469     PADS  ...       -0.060294  StretchHold  RightWrist
# 10314       patient  469     PADS  ...       -5.481484   TouchIndex   LeftWrist
# 10315       patient  469     PADS  ...       -4.422117   TouchIndex  RightWrist
# 10316       patient  469     PADS  ...       -4.469865    TouchNose   LeftWrist
# 10317       patient  469     PADS  ...       -5.108847    TouchNose  RightWrist
#
# [10318 rows x 41 columns]

# %%
#Checking the condition column 
merged_df["condition"].value_counts()
# Out:
# condition
# Parkinson's                 6072
# Healthy                     1738
# Other Movement Disorders    1320
# Essential Tremor             616
# Atypical Parkinsonism        330
# Multiple Sclerosis           242
# Name: count, dtype: int64

# %%
merged_df["condition"].value_counts()
# Out:
# condition
# Parkinson's                 6072
# Healthy                     1738
# Other Movement Disorders    1320
# Essential Tremor             616
# Atypical Parkinsonism        330
# Multiple Sclerosis           242
# Name: count, dtype: int64

# %%
#Filtering out the df frame such that we have onlyy Parkinsons and healthy 
merged_df["condition"] = merged_df["condition"].str.strip().str.replace("’", "'")

merged_df = merged_df[(merged_df["condition"] == "Parkinson's") | (merged_df["condition"] == "Healthy")]

# %%
merged_df.columns
# Out:
# Index(['resource_type', 'id', 'study_id', 'condition', 'disease_comment',
#        'age_at_diagnosis', 'age', 'height', 'weight', 'gender', 'handedness',
#        'appearance_in_kinship', 'effect_of_alcohol_on_tremor', 'label',
#        'patient_id', 'Accelerometer_X_mean', 'Accelerometer_X_std',
#        'Accelerometer_X_max', 'Accelerometer_X_min', 'Accelerometer_Y_mean',
#        'Accelerometer_Y_std', 'Accelerometer_Y_max', 'Accelerometer_Y_min',
#        'Accelerometer_Z_mean', 'Accelerometer_Z_std', 'Accelerometer_Z_max',
#        'Accelerometer_Z_min', 'Gyroscope_X_mean', 'Gyroscope_X_std',
#        'Gyroscope_X_max', 'Gyroscope_X_min', 'Gyroscope_Y_mean',
#        'Gyroscope_Y_std', 'Gyroscope_Y_max', 'Gyroscope_Y_min',
#        'Gyroscope_Z_mean', 'Gyroscope_Z_std', 'Gyroscope_Z_max',
#        'Gyroscope_Z_min', 'task', 'wrist'],
#       dtype='object')

# %%
merged_df
# Out:
#       resource_type   id study_id  ... Gyroscope_Z_min         task       wrist
# 0           patient    1     PADS  ...       -6.042105    CrossArms   LeftWrist
# 1           patient    1     PADS  ...       -6.602785    CrossArms  RightWrist
# 2           patient    1     PADS  ...       -1.383440    DrinkGlas   LeftWrist
# 3           patient    1     PADS  ...       -4.873748    DrinkGlas  RightWrist
# 4           patient    1     PADS  ...       -0.416381  Entrainment   LeftWrist
# ...             ...  ...      ...  ...             ...          ...         ...
# 10313       patient  469     PADS  ...       -0.060294  StretchHold  RightWrist
# 10314       patient  469     PADS  ...       -5.481484   TouchIndex   LeftWrist
# 10315       patient  469     PADS  ...       -4.422117   TouchIndex  RightWrist
# 10316       patient  469     PADS  ...       -4.469865    TouchNose   LeftWrist
# 10317       patient  469     PADS  ...       -5.108847    TouchNose  RightWrist
#
# [7810 rows x 41 columns]

# %%
print(merged_df["label"].value_counts())

print(merged_df["condition"].value_counts())
# Out:
# label
# 1    6072
# 0    1738
# Name: count, dtype: int64
# condition
# Parkinson's    6072
# Healthy        1738
# Name: count, dtype: int64

# %%
merged_df.isnull().sum()
# Out:
# resource_type                  0
# id                             0
# study_id                       0
# condition                      0
# disease_comment                0
# age_at_diagnosis               0
# age                            0
# height                         0
# weight                         0
# gender                         0
# handedness                     0
# appearance_in_kinship          0
# effect_of_alcohol_on_tremor    0
# label                          0
# patient_id                     0
# Accelerometer_X_mean           0
# Accelerometer_X_std            0
# Accelerometer_X_max            0
# Accelerometer_X_min            0
# Accelerometer_Y_mean           0
# Accelerometer_Y_std            0
# Accelerometer_Y_max            0
# Accelerometer_Y_min            0
# Accelerometer_Z_mean           0
# Accelerometer_Z_std            0
# Accelerometer_Z_max            0
# Accelerometer_Z_min            0
# Gyroscope_X_mean               0
# Gyroscope_X_std                0
# Gyroscope_X_max                0
# Gyroscope_X_min                0
# Gyroscope_Y_mean               0
# Gyroscope_Y_std                0
# Gyroscope_Y_max                0
# Gyroscope_Y_min                0
# Gyroscope_Z_mean               0
# Gyroscope_Z_std                0
# Gyroscope_Z_max                0
# Gyroscope_Z_min                0
# task                           0
# wrist                          0
# dtype: int64

# %%
#Dropping features I might not need 
merged_df = merged_df.drop(columns = ["resource_type", "id", "appearance_in_kinship", "effect_of_alcohol_on_tremor", "label" ,"study_id", "disease_comment", "age_at_diagnosis", "age", "height", "weight", "gender", "handedness"])

# %%
merged_df
# Out:
#          condition  patient_id  ...         task       wrist
# 0          Healthy           1  ...    CrossArms   LeftWrist
# 1          Healthy           1  ...    CrossArms  RightWrist
# 2          Healthy           1  ...    DrinkGlas   LeftWrist
# 3          Healthy           1  ...    DrinkGlas  RightWrist
# 4          Healthy           1  ...  Entrainment   LeftWrist
# ...            ...         ...  ...          ...         ...
# 10313  Parkinson's         469  ...  StretchHold  RightWrist
# 10314  Parkinson's         469  ...   TouchIndex   LeftWrist
# 10315  Parkinson's         469  ...   TouchIndex  RightWrist
# 10316  Parkinson's         469  ...    TouchNose   LeftWrist
# 10317  Parkinson's         469  ...    TouchNose  RightWrist
#
# [7810 rows x 28 columns]

# %%
merged_df.isnull().sum()
# Out:
# condition               0
# patient_id              0
# Accelerometer_X_mean    0
# Accelerometer_X_std     0
# Accelerometer_X_max     0
# Accelerometer_X_min     0
# Accelerometer_Y_mean    0
# Accelerometer_Y_std     0
# Accelerometer_Y_max     0
# Accelerometer_Y_min     0
# Accelerometer_Z_mean    0
# Accelerometer_Z_std     0
# Accelerometer_Z_max     0
# Accelerometer_Z_min     0
# Gyroscope_X_mean        0
# Gyroscope_X_std         0
# Gyroscope_X_max         0
# Gyroscope_X_min         0
# Gyroscope_Y_mean        0
# Gyroscope_Y_std         0
# Gyroscope_Y_max         0
# Gyroscope_Y_min         0
# Gyroscope_Z_mean        0
# Gyroscope_Z_std         0
# Gyroscope_Z_max         0
# Gyroscope_Z_min         0
# task                    0
# wrist                   0
# dtype: int64

# %%
merged_df.columns
# Out:
# Index(['condition', 'patient_id', 'Accelerometer_X_mean',
#        'Accelerometer_X_std', 'Accelerometer_X_max', 'Accelerometer_X_min',
#        'Accelerometer_Y_mean', 'Accelerometer_Y_std', 'Accelerometer_Y_max',
#        'Accelerometer_Y_min', 'Accelerometer_Z_mean', 'Accelerometer_Z_std',
#        'Accelerometer_Z_max', 'Accelerometer_Z_min', 'Gyroscope_X_mean',
#        'Gyroscope_X_std', 'Gyroscope_X_max', 'Gyroscope_X_min',
#        'Gyroscope_Y_mean', 'Gyroscope_Y_std', 'Gyroscope_Y_max',
#        'Gyroscope_Y_min', 'Gyroscope_Z_mean', 'Gyroscope_Z_std',
#        'Gyroscope_Z_max', 'Gyroscope_Z_min', 'task', 'wrist'],
#       dtype='object')

# %%
#Preprocessing with scaler numerical columns

numerical_cols = [col for col in merged_df if merged_df[col].dtype == "float64"]
numerical_cols
# Out:
# ['Accelerometer_X_mean',
#  'Accelerometer_X_std',
#  'Accelerometer_X_max',
#  'Accelerometer_X_min',
#  'Accelerometer_Y_mean',
#  'Accelerometer_Y_std',
#  'Accelerometer_Y_max',
#  'Accelerometer_Y_min',
#  'Accelerometer_Z_mean',
#  'Accelerometer_Z_std',
#  'Accelerometer_Z_max',
#  'Accelerometer_Z_min',
#  'Gyroscope_X_mean',
#  'Gyroscope_X_std',
#  'Gyroscope_X_max',
#  'Gyroscope_X_min',
#  'Gyroscope_Y_mean',
#  'Gyroscope_Y_std',
#  'Gyroscope_Y_max',
#  'Gyroscope_Y_min',
#  'Gyroscope_Z_mean',
#  'Gyroscope_Z_std',
#  'Gyroscope_Z_max',
#  'Gyroscope_Z_min']

# %%
#Working with the task column
print(merged_df["task"].value_counts())
print(merged_df["task"].nunique())
# Out:
# task
# CrossArms      710
# DrinkGlas      710
# Entrainment    710
# HoldWeight     710
# LiftHold       710
# PointFinger    710
# RelaxedTask    710
# Relaxed        710
# StretchHold    710
# TouchIndex     710
# TouchNose      710
# Name: count, dtype: int64
# 11

# %% [markdown]
# Doing Visualizations to see correlations

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in numerical_cols:
    sns.scatterplot(x=merged_df[col], y=merged_df['condition'])
    plt.figure(figsize=(4,5))
    plt.title(f'{col} vs Label')
    plt.show()

# %%
corr_matrix = merged_df.drop(columns = ["condition", "task", "patient_id", "wrist"]).corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.figure(figsize = (8,6))
plt.show()

# %%
#Preprocessing and scaling numerical columns 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

merged_df[numerical_cols] = scaler.fit_transform(merged_df[numerical_cols])

# %%
print(merged_df.columns)
# Out:
# Index(['condition', 'patient_id', 'Accelerometer_X_mean',
#        'Accelerometer_X_std', 'Accelerometer_X_max', 'Accelerometer_X_min',
#        'Accelerometer_Y_mean', 'Accelerometer_Y_std', 'Accelerometer_Y_max',
#        'Accelerometer_Y_min', 'Accelerometer_Z_mean', 'Accelerometer_Z_std',
#        'Accelerometer_Z_max', 'Accelerometer_Z_min', 'Gyroscope_X_mean',
#        'Gyroscope_X_std', 'Gyroscope_X_max', 'Gyroscope_X_min',
#        'Gyroscope_Y_mean', 'Gyroscope_Y_std', 'Gyroscope_Y_max',
#        'Gyroscope_Y_min', 'Gyroscope_Z_mean', 'Gyroscope_Z_std',
#        'Gyroscope_Z_max', 'Gyroscope_Z_min', 'task', 'wrist'],
#       dtype='object')

# %%
#One hot encoding the categorical columns 
cat_cols  = [col for col in merged_df if merged_df[col].dtype == "object"]
print(cat_cols)
# Out:
# ['condition', 'task', 'wrist']

# %%
#Finding unique values
for col in cat_cols:
    print()
    print(merged_df[col].value_counts())
    if col == "task":
        task_series = merged_df[col].value_counts()
# Out:
# condition
# Parkinson's    6072
# Healthy        1738
# Name: count, dtype: int64
#
# task
# CrossArms      710
# DrinkGlas      710
# Entrainment    710
# HoldWeight     710
# LiftHold       710
# PointFinger    710
# RelaxedTask    710
# Relaxed        710
# StretchHold    710
# TouchIndex     710
# TouchNose      710
# Name: count, dtype: int64
#
# wrist
# LeftWrist     3905
# RightWrist    3905
# Name: count, dtype: int64

# %%
#Working on the wrist 
merged_df = pd.get_dummies(merged_df, columns = ["wrist"])

# %%
print(task_series)
print(type(task_series))

list_num = (range(len(task_series)))

dict_list ={task: count for count, task in enumerate(task_series.index)}

print(dict_list)

merged_df["task"] = merged_df["task"].replace(dict_list)
# Out:
# task
# CrossArms      710
# DrinkGlas      710
# Entrainment    710
# HoldWeight     710
# LiftHold       710
# PointFinger    710
# RelaxedTask    710
# Relaxed        710
# StretchHold    710
# TouchIndex     710
# TouchNose      710
# Name: count, dtype: int64
# <class 'pandas.core.series.Series'>
# {'CrossArms': 0, 'DrinkGlas': 1, 'Entrainment': 2, 'HoldWeight': 3, 'LiftHold': 4, 'PointFinger': 5, 'RelaxedTask': 6, 'Relaxed': 7, 'StretchHold': 8, 'TouchIndex': 9, 'TouchNose': 10}
# /tmp/ipykernel_2834097/2479888257.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_df["task"] = merged_df["task"].replace(dict_list)

# %%
#Saving preprocessed file 
merged_df.to_csv("preprocessed_typing.csv", index=False)

# %%
merged_df
# Out:
#          condition  patient_id  ...  wrist_LeftWrist  wrist_RightWrist
# 0          Healthy           1  ...             True             False
# 1          Healthy           1  ...            False              True
# 2          Healthy           1  ...             True             False
# 3          Healthy           1  ...            False              True
# 4          Healthy           1  ...             True             False
# ...            ...         ...  ...              ...               ...
# 10313  Parkinson's         469  ...            False              True
# 10314  Parkinson's         469  ...             True             False
# 10315  Parkinson's         469  ...            False              True
# 10316  Parkinson's         469  ...             True             False
# 10317  Parkinson's         469  ...            False              True
#
# [7810 rows x 29 columns]

# %%
#Do feature importance and stuff and make sure 1st 2 pages of app are working from there proceed to 3rd page, which graps audio recording

#Break through tech due today --> damn

#The project with Majoie -- just train on a neural network and evalaute test performance
