# %%
#Spiral dataset unzipping
import zipfile
import os 

with zipfile.ZipFile("/users/imbahndu/Desktop/Columbia DBM/parkinson+disease+spiral+drawings+using+digitized+graphics+tablet.zip", "r" ) as filename:
    filename.extractall()

# %%
# !pip install datasets
from datasets import load_dataset

ds = load_dataset("PD-Project/Parkinsons-Disease-DaT-Dataset")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 494 kB 4.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 133 kB 70.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 116 kB 101.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 515 kB 62.0 MB/s eta 0:00:01
# ...
#   Using cached fsspec-2025.3.0-py3-none-any.whl (193 kB)
# ...
#      |████████████████████████████████| 193 kB 100.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 111.8 MB/s eta 0:00:01
# ...
#   WARNING: Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /users/imbahndu/.local/lib/python3.9/site-packages
#   sysconfig: /users/imbahndu/.local/lib64/python3.9/site-packages
#   WARNING: Additional context:
#   user = True
#   home = None
#   root = None
#   prefix = None
#   Attempting uninstall: fsspec
# ...

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 384
#     })
# })

# %%
import matplotlib.pyplot as plt

# Load a handful of samples
sample_batch = ds['train'].select(range(5))  # Adjust number if you'd like

# Plot each image
for example in sample_batch:
    image = example['image']
    label = example['label']
    
    plt.imshow(image)
    plt.title(f"Label: {label}")
    plt.axis('off')
    plt.show()
