# %%
#Unzipping all the files to ease preprocessing

import zipfile
import os

# Unzip user metadata
with zipfile.ZipFile("/users/imbahndu/Desktop/Columbia DBM/tappy-keystroke-data-1.0.0/Archived-users.zip", 'r') as zip_ref:
    zip_ref.extractall('user_info')

# Unzip keystroke data
with zipfile.ZipFile("/users/imbahndu/Desktop/Columbia DBM/tappy-keystroke-data-1.0.0/Archived-Data.zip", 'r') as zip_ref:
    zip_ref.extractall('keystroke_data')

# %%
import os
import pandas as pd

keystroke_records = []

# Folder containing all the .txt files
data_folder = 'keystroke_data/Tappy Data'

# Loop through each file in the folder and finding the ones ending with .txt
for file in os.listdir(data_folder):
    if file.endswith('.txt'):
        file_path = os.path.join(data_folder, file)
        #Create a dataframe for each file 
        try:
            df = pd.read_csv(
                file_path,
                sep='\t',
                header=None,
                on_bad_lines="skip",
                #the names are extracted from the dataset where I pulled this information
                names=[
                     "UserKey",'Date', 'Timestamp',
                    'Hand', 'HoldTime', 'Direction',
                    'LatencyTime', 'FlightTime'
                ], low_memory=False, usecols=range(8)
            )
            #Creating a new df column to trace the file, but will drop it for ml project
            df['Filename'] = file  # optional for traceability
            keystroke_records.append(df)
        except Exception as e:
            print(f"Failed to read {file}: {e}")

# Combine all parsed files
if keystroke_records:
    keystrokes_df = pd.concat(keystroke_records, ignore_index=True)
    print("Successfully loaded keystroke data:")
else:
    print("No valid keystroke files found.")


keystrokes_df
# Out:
# Successfully loaded keystroke data:
#             UserKey    Date     Timestamp Hand HoldTime Direction LatencyTime  \
# 0        0EA27ICBLF  160722  18:41:04.336    L   0101.6        LL      0234.4
# 1        0EA27ICBLF  160722  18:42:14.070    L   0085.9        LL      0437.5
# 2        0EA27ICBLF  160722  18:42:14.273    L   0078.1        LL      0210.9
# 3        0EA27ICBLF  160722  18:42:14.617    L   0062.5        LL      0359.4
# 4        0EA27ICBLF  160722  18:42:15.586    S   0125.0        LS      0187.5
# ...             ...     ...           ...  ...      ...       ...         ...
# 9316853  ZYWLN4JVLA  170126  13:56:20.117    L   0195.3        RL      0425.8
# 9316854  ZYWLN4JVLA  170126  13:56:20.242    R   0105.5        LR      0214.8
# 9316855  ZYWLN4JVLA  170126  13:56:33.625    L   0168.0        LL      0332.0
# 9316856  ZYWLN4JVLA  170126  13:56:33.836    L   0097.7        LL      0281.3
# 9316857  ZYWLN4JVLA  170126  13:56:34.066    L   0168.0        LL      0160.2
#
#         FlightTime             Filename
# 0           0156.3  0EA27ICBLF_1607.txt
# 1           0359.4  0EA27ICBLF_1607.txt
# 2           0125.0  0EA27ICBLF_1607.txt
# 3           0281.3  0EA27ICBLF_1607.txt
# 4           0093.8  0EA27ICBLF_1607.txt
# ...            ...                  ...
# 9316853      261.7  ZYWLN4JVLA_1701.txt
# 9316854       19.5  ZYWLN4JVLA_1701.txt
# 9316855       15.6  ZYWLN4JVLA_1701.txt
# 9316856      113.3  ZYWLN4JVLA_1701.txt
# 9316857       62.5  ZYWLN4JVLA_1701.txt
#
# [9316858 rows x 9 columns]

# %%
#Doing thesame thing above for user_info 

user_info_list = []

user_folder = "/users/imbahndu/Desktop/Columbia DBM/tappy-keystroke-data-1.0.0/user_info/Archived users"

#Looping through each file 
for file in os.listdir(user_folder):
    if file.endswith(".txt"):
        #Opening them
        filename = os.path.join(user_folder, file)
        user_data = {}
        #Inspecting the way the user information is encrypted to decrypt it
        with open(filename, "r" ) as f:
            #looping through each file
            for line in f:
                if ":" in line:
                    #append the text before a key in the user_data dictionary and adding the association as the value
                    key, value = line.strip().split(":", 1)
                    print(key, value)
                    user_data[key.strip()] = value.strip()
                    #Adding the file name for traceabililty 
        user_data["UserKey"] = file.replace(".txt", " ")
        user_data["UserKey"] = file.replace("User_", " ")
                    #Appending final results
        user_info_list.append(user_data)
        print(user_data)
print(user_info_list)
user_df = pd.DataFrame(user_info_list)
# Out:
# BirthYear  1952
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2000
# Sided  Left
# UPDRS  Don't know
# Impact  Severe
# Levadopa  True
# DA  True
# MAOB  False
# Other  False
# {'BirthYear': '1952', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2000', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 0EA27ICBLF.txt'}
# BirthYear  1959
# Gender  Female
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1959', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 0QAZFRHQHW.txt'}
# BirthYear  1946
# Gender  Female
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1946', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 0WTDIGPSBZ.txt'}
# BirthYear  1944
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1944', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 1HOEBIGASW.txt'}
# BirthYear  1953
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2017
# Sided  Left
# UPDRS  Don't know
# Impact  Medium
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1953', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2017', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 1WMVCCU4RH.txt'}
# BirthYear  1936
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1936', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 1XNJCXS3EY.txt'}
# BirthYear  1958
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2013
# Sided  Right
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1958', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2013', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 2JTCBKUP8T.txt'}
# BirthYear  1951
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2003
# Sided  Left
# UPDRS  Don't know
# Impact  Severe
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1951', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2003', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 2X17VCRRQA.txt'}
# BirthYear  1961
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2015
# Sided  Left
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1961', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2015', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 310NXPGJPD.txt'}
# BirthYear  1942
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2013
# Sided  Right
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  True
# MAOB  False
# Other  False
# {'BirthYear': '1942', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2013', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 39KQRZCESF.txt'}
# BirthYear  1936
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1936', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 3DIXPRIOSW.txt'}
# BirthYear
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2016
# Sided  Left
# UPDRS  Don't know
# Impact  Medium
# Levadopa  False
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2016', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 3LBXTMXULC.txt'}
# BirthYear
# Gender  Female
# Parkinsons  True
# Tremors  False
# DiagnosisYear
# Sided  None
# UPDRS  Don't know
# Impact
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 3MZWDTW7CC.txt'}
# BirthYear  1950
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2010
# Sided  None
# UPDRS  Don't know
# Impact  Mild
# Levadopa  False
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1950', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2010', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 48DZPAJ5NS.txt'}
# BirthYear  1953
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2012
# Sided  Left
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  True
# MAOB  True
# Other  False
# {'BirthYear': '1953', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2012', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'True', 'Other': 'False', 'UserKey': ' 4GUYFBZMK9.txt'}
# BirthYear
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 4XPHKKBXS6.txt'}
# BirthYear  1944
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2016
# Sided  Right
# UPDRS  2
# Impact  Severe
# Levadopa  False
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1944', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2016', 'Sided': 'Right', 'UPDRS': '2', 'Impact': 'Severe', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 5ARV4LHEJ0.txt'}
# BirthYear  1954
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1954', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 5CECBJXGB3.txt'}
# BirthYear  1943
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2009
# Sided  Right
# UPDRS  Don't know
# Impact  Mild
# Levadopa  False
# DA  True
# MAOB  False
# Other  True
# {'BirthYear': '1943', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2009', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'False', 'DA': 'True', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 5PQVTWULAC.txt'}
# BirthYear  1941
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2017
# Sided  None
# UPDRS  Don't know
# Impact  Mild
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1941', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2017', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 5USOYSDCXB.txt'}
# BirthYear  1967
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2016
# Sided  None
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1967', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2016', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 5YFAPLRCMD.txt'}
# BirthYear  1956
# Gender  Female
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1956', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 6LB9FQABZQ.txt'}
# BirthYear  1947
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2014
# Sided  Left
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1947', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2014', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 6R9IGYWVWT.txt'}
# BirthYear
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear
# Sided  Left
# UPDRS  4
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '', 'Sided': 'Left', 'UPDRS': '4', 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 6WBXSDG5BB.txt'}
# BirthYear  1947
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2004
# Sided  Left
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  True
# MAOB  False
# Other  True
# {'BirthYear': '1947', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2004', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 6YXFEMHYZI.txt'}
# BirthYear  1942
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2012
# Sided  None
# UPDRS  Don't know
# Impact  Severe
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1942', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2012', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 7HTEQAAWWO.txt'}
# BirthYear  1939
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2010
# Sided  Right
# UPDRS  Don't know
# Impact  Medium
# Levadopa  False
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1939', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2010', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 7QVQD5IJEH.txt'}
# BirthYear  1938
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2016
# Sided  Right
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1938', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2016', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 7XS9VOLXWU.txt'}
# BirthYear
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 81NEUZEBXI.txt'}
# BirthYear  1950
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2012
# Sided  Right
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1950', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2012', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 8EY6NZAKCI.txt'}
# BirthYear
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2012
# Sided  Right
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  True
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2012', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 8MERXVINPN.txt'}
# BirthYear  1947
# Gender  Female
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1947', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 8O9IAIA9L1.txt'}
# BirthYear  1935
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2013
# Sided  Right
# UPDRS  Don't know
# Impact  Severe
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1935', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2013', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 8TEUUGQBYB.txt'}
# BirthYear  1947
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2013
# Sided  Right
# UPDRS  Don't know
# Impact  Medium
# Levadopa  False
# DA  True
# MAOB  True
# Other  False
# {'BirthYear': '1947', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2013', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'False', 'DA': 'True', 'MAOB': 'True', 'Other': 'False', 'UserKey': ' 927ZLCPEJM.txt'}
# BirthYear  1952
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2010
# Sided  None
# UPDRS  Don't know
# Impact  Medium
# Levadopa  False
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1952', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2010', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 95S93AXF86.txt'}
# BirthYear
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2014
# Sided  Right
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2014', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 9GBSZXI2BB.txt'}
# BirthYear  1949
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2014
# Sided  Right
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1949', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2014', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 9JRHCGCWAZ.txt'}
# BirthYear  1951
# Gender  Female
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1951', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 9RCEHVGNCJ.txt'}
# BirthYear
# Gender  Female
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2016
# Sided  None
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2016', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 9TUXDIR9EE.txt'}
# BirthYear  1943
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2016
# Sided  Left
# UPDRS  1
# Impact  Mild
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1943', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2016', 'Sided': 'Left', 'UPDRS': '1', 'Impact': 'Mild', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 9ZRBC5WOZR.txt'}
# BirthYear
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2016
# Sided  Left
# UPDRS  Don't know
# Impact  Medium
# Levadopa  False
# DA  True
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2016', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'False', 'DA': 'True', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' ACSKCOJC06.txt'}
# BirthYear  1943
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2013
# Sided  None
# UPDRS  Don't know
# Impact  Severe
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1943', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2013', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' AFNOZ1KI1M.txt'}
# BirthYear
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear
# Sided  Left
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' AFQWSP8ARK.txt'}
# BirthYear  1930
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2007
# Sided  Left
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1930', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2007', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' AJHHNPKG0K.txt'}
# BirthYear  1949
# Gender  Female
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2004
# Sided  Left
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1949', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2004', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' AJIGSB2YPW.txt'}
# BirthYear  1955
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear
# Sided  None
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  True
# Other  True
# {'BirthYear': '1955', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'True', 'Other': 'True', 'UserKey': ' ARUGT4UL2R.txt'}
# BirthYear  1961
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear
# Sided  Right
# UPDRS  Don't know
# Impact  Severe
# Levadopa  True
# DA  True
# MAOB  True
# Other  True
# {'BirthYear': '1961', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'True', 'Other': 'True', 'UserKey': ' ASP8RSNO73.txt'}
# BirthYear  1948
# Gender  Female
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1948', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' AVNGRDUXE5.txt'}
# BirthYear  1949
# Gender  Female
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1949', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' AXXXXBBCCH.txt'}
# BirthYear  1941
# Gender  Female
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2016
# Sided  None
# UPDRS  Don't know
# Impact  Severe
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1941', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2016', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' B4NL4SV9ZC.txt'}
# BirthYear  1952
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  1996
# Sided  Left
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1952', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '1996', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' BBCWCBNBPR.txt'}
# BirthYear  1960
# Gender  Female
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1960', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' BENXJNDSC4.txt'}
# BirthYear  1951
# Gender  Female
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1951', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' BFXNVL50DC.txt'}
# BirthYear  1937
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2016
# Sided  Right
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1937', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2016', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' BIGWMXFU3B.txt'}
# BirthYear
# Gender  Female
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2015
# Sided  None
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  True
# Other  True
# {'BirthYear': '', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2015', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'True', 'Other': 'True', 'UserKey': ' BZ8MQ2TBMS.txt'}
# BirthYear
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear
# Sided  Right
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' C6UGS6P0J0.txt'}
# BirthYear  1946
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2015
# Sided  Left
# UPDRS  Don't know
# Impact  Mild
# Levadopa  False
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1946', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2015', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' CAXCJIKLYM.txt'}
# BirthYear
# Gender  Female
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2006
# Sided  None
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2006', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' CEU6KM05RU.txt'}
# BirthYear
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' COK8G1W7JY.txt'}
# BirthYear  1946
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2016
# Sided  Right
# UPDRS  Don't know
# Impact  Severe
# Levadopa  False
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1946', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2016', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' CPSM4LIXDS.txt'}
# BirthYear  1954
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  1998
# Sided  Left
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  True
# MAOB  False
# Other  False
# {'BirthYear': '1954', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '1998', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' CYC6IZJYTE.txt'}
# BirthYear  1948
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2015
# Sided  None
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1948', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2015', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' E0TBSMYHQI.txt'}
# BirthYear  1936
# Gender  Female
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1936', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' E0XRQVF05S.txt'}
# BirthYear  1960
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2015
# Sided  None
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1960', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2015', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' E1E2I8HUGC.txt'}
# BirthYear  1951
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2013
# Sided  Right
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1951', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2013', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' E7UA8EHENF.txt'}
# BirthYear  1953
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2004
# Sided  Left
# UPDRS  3
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1953', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2004', 'Sided': 'Left', 'UPDRS': '3', 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' EBGLZDVO5S.txt'}
# BirthYear  1951
# Gender  Female
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2016
# Sided  Left
# UPDRS  Don't know
# Impact  Mild
# Levadopa  False
# DA  False
# MAOB  True
# Other  False
# {'BirthYear': '1951', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2016', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'True', 'Other': 'False', 'UserKey': ' EF9XEFXPBN.txt'}
# BirthYear  1951
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2005
# Sided  None
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1951', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2005', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' EKG57AN0N6.txt'}
# BirthYear  1945
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1945', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' EMYGMAIB2L.txt'}
# BirthYear
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2010
# Sided  None
# UPDRS  Don't know
# Impact  Severe
# Levadopa  True
# DA  False
# MAOB  True
# Other  False
# {'BirthYear': '', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2010', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'True', 'Other': 'False', 'UserKey': ' ERFIZ5O8FM.txt'}
# BirthYear  1943
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2007
# Sided  Left
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1943', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2007', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' EX8J9DGRSY.txt'}
# BirthYear  1949
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2015
# Sided  Right
# UPDRS  Don't know
# Impact  Mild
# Levadopa  False
# DA  True
# MAOB  False
# Other  False
# {'BirthYear': '1949', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2015', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'False', 'DA': 'True', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' EZF9NAHLOU.txt'}
# BirthYear  1961
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1961', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' F56FSV2EP7.txt'}
# BirthYear  1936
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1936', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' F8KU8UP2SZ.txt'}
# BirthYear  1958
# Gender  Female
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1958', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' FFNMFHHSZJ.txt'}
# BirthYear  1948
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2014
# Sided  Right
# UPDRS  Don't know
# Impact  Medium
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1948', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2014', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' FHEOPKL3QQ.txt'}
# BirthYear  1940
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  1996
# Sided  Right
# UPDRS  Don't know
# Impact  Severe
# Levadopa  True
# DA  True
# MAOB  False
# Other  True
# {'BirthYear': '1940', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '1996', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' FIWPKLWCT5.txt'}
# BirthYear  1943
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1943', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' FX9KOOZRZL.txt'}
# BirthYear  1943
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2009
# Sided  Left
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1943', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2009', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' FXC5YFXZ0K.txt'}
# BirthYear  1952
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1952', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' G6OE5CXQPY.txt'}
# BirthYear  1929
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1929', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' GEYWAGTINR.txt'}
# BirthYear  1949
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2009
# Sided  Left
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1949', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2009', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' GHRLW1IJRV.txt'}
# BirthYear  1949
# Gender  Female
# Parkinsons  True
# Tremors  False
# DiagnosisYear  1995
# Sided  Right
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  True
# MAOB  False
# Other  False
# {'BirthYear': '1949', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '1995', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' GMCJGJHMZN.txt'}
# BirthYear  1938
# Gender  Female
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1938', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' GN1CUIPUTJ.txt'}
# BirthYear  1965
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1965', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' GN3N4ZNCV9.txt'}
# BirthYear  1945
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2006
# Sided  Left
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1945', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2006', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' GOCJ4TNPII.txt'}
# BirthYear  1941
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2000
# Sided  Left
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1941', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2000', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' GRPUBQLE4F.txt'}
# BirthYear  1956
# Gender  Female
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2008
# Sided  None
# UPDRS  Don't know
# Impact  Severe
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1956', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2008', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' GUDRVXO6RX.txt'}
# BirthYear  1952
# Gender  Female
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1952', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' H08AW2YBAJ.txt'}
# BirthYear  1985
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2013
# Sided  Left
# UPDRS  Don't know
# Impact  Mild
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1985', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2013', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' HAEZ2A3NM5.txt'}
# BirthYear  1956
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2011
# Sided  Right
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1956', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2011', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' HB2JCE24IE.txt'}
# BirthYear
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2014
# Sided  None
# UPDRS  Don't know
# Impact  Medium
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2014', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' HQGUVYLVZH.txt'}
# BirthYear
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2015
# Sided  Left
# UPDRS  Don't know
# Impact  Medium
# Levadopa  False
# DA  True
# MAOB  False
# Other  True
# {'BirthYear': '', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2015', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'False', 'DA': 'True', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' HVSWQYNG2N.txt'}
# BirthYear  1937
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1937', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' HYGNDIWHSC.txt'}
# BirthYear  1947
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2014
# Sided  None
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1947', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2014', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' I3U47MF5UF.txt'}
# BirthYear  1952
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2016
# Sided  None
# UPDRS  Don't know
# Impact  Mild
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1952', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2016', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' ICXFP2WKAU.txt'}
# BirthYear  1940
# Gender  Female
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1940', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' IDYIDJBAXF.txt'}
# BirthYear  1943
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2013
# Sided  None
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1943', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2013', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' IDZHIUK2W2.txt'}
# BirthYear  1961
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2008
# Sided  Right
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1961', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2008', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' ITWTZ5F3VW.txt'}
# BirthYear  1940
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2015
# Sided  Left
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1940', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2015', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' IZBOYJGXXB.txt'}
# BirthYear  1940
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2008
# Sided  Right
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1940', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2008', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' J3QZ0MCD1Y.txt'}
# BirthYear  1941
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2006
# Sided  None
# UPDRS  Don't know
# Impact  Severe
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1941', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2006', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' JDWYGP605O.txt'}
# BirthYear  1939
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2016
# Sided  None
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1939', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2016', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' JHBOKKHOQW.txt'}
# BirthYear  1985
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2014
# Sided  None
# UPDRS  Don't know
# Impact  Mild
# Levadopa  False
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1985', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2014', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' JIRZDKEJQN.txt'}
# BirthYear  1947
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2007
# Sided  Right
# UPDRS  3
# Impact  Severe
# Levadopa  True
# DA  True
# MAOB  False
# Other  False
# {'BirthYear': '1947', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2007', 'Sided': 'Right', 'UPDRS': '3', 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' JMIVIRFQRR.txt'}
# BirthYear
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2008
# Sided  Right
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2008', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' JMYZ5IKGWE.txt'}
# BirthYear  1949
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2015
# Sided  None
# UPDRS  Don't know
# Impact  Mild
# Levadopa  False
# DA  False
# MAOB  True
# Other  False
# {'BirthYear': '1949', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2015', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'True', 'Other': 'False', 'UserKey': ' JQ0YSY0AYO.txt'}
# BirthYear  1947
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1947', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' JWGIQXYUDJ.txt'}
# BirthYear  1954
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2015
# Sided  Left
# UPDRS  Don't know
# Impact  Mild
# Levadopa  False
# DA  True
# MAOB  True
# Other  False
# ...
# BirthYear  1959
# Gender  Female
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1959', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' WXNQ0QM0XD.txt'}
# BirthYear
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear
# Sided  Left
# UPDRS  Don't know
# Impact
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': '', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' WY25WHLA9D.txt'}
# BirthYear  1953
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2015
# Sided  None
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  True
# MAOB  False
# Other  False
# {'BirthYear': '1953', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2015', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' X7PEJ5EG77.txt'}
# BirthYear  1957
# Gender  Female
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2016
# Sided  Right
# UPDRS  Don't know
# Impact  Mild
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1957', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2016', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' XPHHPHIVZ4.txt'}
# BirthYear
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' XQIXWF0BXG.txt'}
# BirthYear  1970
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2007
# Sided  Left
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  True
# MAOB  False
# Other  False
# {'BirthYear': '1970', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2007', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' XWAX2IHF3O.txt'}
# BirthYear  1929
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1929', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' YAJFHG6OHD.txt'}
# BirthYear  1945
# Gender  Female
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2009
# Sided  Left
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1945', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2009', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' YFZEXV85OS.txt'}
# BirthYear  1958
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2015
# Sided  Right
# UPDRS  Don't know
# Impact  Mild
# Levadopa  False
# DA  True
# MAOB  False
# Other  False
# {'BirthYear': '1958', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2015', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'False', 'DA': 'True', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' YI43UM1CEH.txt'}
# BirthYear  1934
# Gender  Female
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1934', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' YIA9DW5AGQ.txt'}
# BirthYear  1927
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2010
# Sided  None
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1927', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2010', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' YNVRRFC8S4.txt'}
# BirthYear  1948
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1948', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' YQSGN9BMVK.txt'}
# BirthYear
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' YWAWVFZZZE.txt'}
# BirthYear  1953
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2016
# Sided  Right
# UPDRS  Don't know
# Impact  Mild
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1953', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2016', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' YWMIQIQND3.txt'}
# BirthYear  1928
# Gender  Male
# Parkinsons  False
# Tremors  False
# DiagnosisYear   ------
# Sided  None
# UPDRS  Don't know
# Impact   ------
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1928', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' YYPKGX6B24.txt'}
# BirthYear  1947
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2015
# Sided  Right
# UPDRS  Don't know
# Impact  Mild
# Levadopa  False
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1947', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2015', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' Z2UPVHHGBE.txt'}
# BirthYear  1937
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2015
# Sided  Right
# UPDRS  Don't know
# Impact  Severe
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1937', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2015', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' ZCPALNB4ZM.txt'}
# BirthYear
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear
# Sided  None
# UPDRS  Don't know
# Impact
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' ZEA4RST93H.txt'}
# BirthYear  1949
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2015
# Sided  None
# UPDRS  Don't know
# Impact  Medium
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1949', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2015', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' ZI1KGKLCD5.txt'}
# BirthYear  1946
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2004
# Sided  Right
# UPDRS  Don't know
# Impact  Severe
# Levadopa  True
# DA  True
# MAOB  False
# Other  True
# {'BirthYear': '1946', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2004', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' ZIUU38ZJXA.txt'}
# BirthYear  1942
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2014
# Sided  Right
# UPDRS  Don't know
# Impact  Medium
# Levadopa  False
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1942', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2014', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' ZPXSHZSGKI.txt'}
# BirthYear
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2013
# Sided  None
# UPDRS  Don't know
# Impact  Medium
# Levadopa  False
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2013', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' ZQ4UHHUPNZ.txt'}
# BirthYear  1957
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2008
# Sided  Left
# UPDRS  Don't know
# Impact  Severe
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1957', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2008', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' ZT9ASWFCFS.txt'}
# BirthYear  1942
# Gender  Male
# Parkinsons  True
# Tremors  False
# DiagnosisYear  2016
# Sided  None
# UPDRS  Don't know
# Impact  Mild
# Levadopa  True
# DA  False
# MAOB  False
# Other  False
# {'BirthYear': '1942', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2016', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' ZWBPPNQCUX.txt'}
# BirthYear  1942
# Gender  Male
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2013
# Sided  None
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  False
# MAOB  False
# Other  True
# {'BirthYear': '1942', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2013', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' ZWHGXDUDLG.txt'}
# BirthYear
# Gender  Female
# Parkinsons  True
# Tremors  True
# DiagnosisYear  2015
# Sided  Right
# UPDRS  Don't know
# Impact  Medium
# Levadopa  False
# DA  True
# MAOB  False
# Other  False
# {'BirthYear': '', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2015', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'False', 'DA': 'True', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' ZY9CCHSPF2.txt'}
# BirthYear
# Gender  Female
# Parkinsons  True
# Tremors  False
# DiagnosisYear
# Sided  Right
# UPDRS  Don't know
# Impact  Medium
# Levadopa  True
# DA  True
# MAOB  True
# Other  True
# {'BirthYear': '', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'True', 'Other': 'True', 'UserKey': ' ZYWLN4JVLA.txt'}
# [{'BirthYear': '1952', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2000', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 0EA27ICBLF.txt'}, {'BirthYear': '1959', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 0QAZFRHQHW.txt'}, {'BirthYear': '1946', 'Gender': 'Female', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 0WTDIGPSBZ.txt'}, {'BirthYear': '1944', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 1HOEBIGASW.txt'}, {'BirthYear': '1953', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2017', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 1WMVCCU4RH.txt'}, {'BirthYear': '1936', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 1XNJCXS3EY.txt'}, {'BirthYear': '1958', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2013', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 2JTCBKUP8T.txt'}, {'BirthYear': '1951', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2003', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Severe', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 2X17VCRRQA.txt'}, {'BirthYear': '1961', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2015', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 310NXPGJPD.txt'}, {'BirthYear': '1942', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2013', 'Sided': 'Right', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 39KQRZCESF.txt'}, {'BirthYear': '1936', 'Gender': 'Male', 'Parkinsons': 'False', 'Tremors': 'False', 'DiagnosisYear': '------', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '------', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 3DIXPRIOSW.txt'}, {'BirthYear': '', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'True', 'DiagnosisYear': '2016', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 3LBXTMXULC.txt'}, {'BirthYear': '', 'Gender': 'Female', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': '', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'False', 'UserKey': ' 3MZWDTW7CC.txt'}, {'BirthYear': '1950', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2010', 'Sided': 'None', 'UPDRS': "Don't know", 'Impact': 'Mild', 'Levadopa': 'False', 'DA': 'False', 'MAOB': 'False', 'Other': 'True', 'UserKey': ' 48DZPAJ5NS.txt'}, {'BirthYear': '1953', 'Gender': 'Male', 'Parkinsons': 'True', 'Tremors': 'False', 'DiagnosisYear': '2012', 'Sided': 'Left', 'UPDRS': "Don't know", 'Impact': 'Medium', 'Levadopa': 'True', 'DA': 'True', 'MAOB': 'True', 'Other': 'False', 'UserK ...

# %%
print(user_df)
# Out:
#     BirthYear  Gender Parkinsons Tremors DiagnosisYear  Sided       UPDRS  \
# 0        1952  Female       True    True          2000   Left  Don't know
# 1        1959  Female      False   False        ------   None  Don't know
# 2        1946  Female      False   False        ------   None  Don't know
# 3        1944    Male      False   False        ------   None  Don't know
# 4        1953    Male       True    True          2017   Left  Don't know
# ..        ...     ...        ...     ...           ...    ...         ...
# 222      1957  Female       True    True          2008   Left  Don't know
# 223      1942    Male       True   False          2016   None  Don't know
# 224      1942    Male       True    True          2013   None  Don't know
# 225            Female       True    True          2015  Right  Don't know
# 226            Female       True   False                Right  Don't know
#
#      Impact Levadopa     DA   MAOB  Other          UserKey
# 0    Severe     True   True  False  False   0EA27ICBLF.txt
# 1    ------    False  False  False  False   0QAZFRHQHW.txt
# 2    ------    False  False  False  False   0WTDIGPSBZ.txt
# 3    ------    False  False  False  False   1HOEBIGASW.txt
# 4    Medium    False  False  False  False   1WMVCCU4RH.txt
# ..      ...      ...    ...    ...    ...              ...
# 222  Severe     True  False  False   True   ZT9ASWFCFS.txt
# 223    Mild     True  False  False  False   ZWBPPNQCUX.txt
# 224  Medium     True  False  False   True   ZWHGXDUDLG.txt
# 225  Medium    False   True  False  False   ZY9CCHSPF2.txt
# 226  Medium     True   True   True   True   ZYWLN4JVLA.txt
#
# [227 rows x 13 columns]

# %%
user_df["UserKey"]
# Out:
# 0       0EA27ICBLF.txt
# 1       0QAZFRHQHW.txt
# 2       0WTDIGPSBZ.txt
# 3       1HOEBIGASW.txt
# 4       1WMVCCU4RH.txt
#             ...
# 222     ZT9ASWFCFS.txt
# 223     ZWBPPNQCUX.txt
# 224     ZWHGXDUDLG.txt
# 225     ZY9CCHSPF2.txt
# 226     ZYWLN4JVLA.txt
# Name: UserKey, Length: 227, dtype: object

# %%
#Replacing instances of .txt with an empty string to ease concatenation 
user_df["UserKey"] = user_df['UserKey'].str.replace(".txt", " ", case=False)
user_df["UserKey"]
# Out:
# 0       0EA27ICBLF
# 1       0QAZFRHQHW
# 2       0WTDIGPSBZ
# 3       1HOEBIGASW
# 4       1WMVCCU4RH
#            ...
# 222     ZT9ASWFCFS
# 223     ZWBPPNQCUX
# 224     ZWHGXDUDLG
# 225     ZY9CCHSPF2
# 226     ZYWLN4JVLA
# Name: UserKey, Length: 227, dtype: object

# %%
k#Getting rid of extra characters within the file
eystrokes_df['UserKey'] = keystrokes_df['Filename'].str.extract(r'([A-Z0-9]+)', expand=False)
keystrokes_df["UserKey"]
# Out:
# 0          0EA27ICBLF
# 1          0EA27ICBLF
# 2          0EA27ICBLF
# 3          0EA27ICBLF
# 4          0EA27ICBLF
#               ...
# 9316853    ZYWLN4JVLA
# 9316854    ZYWLN4JVLA
# 9316855    ZYWLN4JVLA
# 9316856    ZYWLN4JVLA
# 9316857    ZYWLN4JVLA
# Name: UserKey, Length: 9316858, dtype: object

# %%
#Making everything consistent to facilitate merging, removing whitespace and making everything upper case
keystrokes_df['UserKey'] = keystrokes_df['UserKey'].str.strip().str.upper()
user_df['UserKey'] = user_df['UserKey'].str.strip().str.upper()

# %%
# Preview which keys exist in both
print("UserKeys in keystrokes not in user_df:", set(keystrokes_df['UserKey']) - set(user_df['UserKey']))
print("UserKeys in user_df not in keystrokes:", set(user_df['UserKey']) - set(keystrokes_df['UserKey']))
# Out:
# UserKeys in keystrokes not in user_df: {'7OIX84KINL', 'TQCMYNHOSM', 'WHTIJRQSYC', 'JZVDCNBT1S', 'UURLOSDUOA', 'GDGG19NBH7', 'PHOPRDDRXM', 'YCQJAEI7RN', 'L9ULZGDITG', 'MFAQFDW3IH', 'UFMGBC58XD', '0NMZ9JBBHI', '6VH7AFDQ32', 'Z1QLXS3DGS', '9ALACHPPUR', 'ZFADOEIUOD', 'VDKQJZARYF', 'AEKGFUEQUU', 'SEVJ2WXCKH', 'M6MUS5WY6N', 'NKKUDKDMGQ', 'KE21ILBSOI', '4IE6CIRI0V', 'KLM4CVXNRB', 'QPRYN1F9BZ', '1BMKGIOSHF', 'QEYMRM1ZSM', 'UMZFEO7IAG', 'XZ9HNUO4KO', 'S5FSMHZEYI', 'TLR6R7C7AP', 'RWPUNZZ3EF', 'PESPWEVTGF', 'RTBOZILJFT', 'YACDBXUNSA', '3HYXJCTCNT', 'ZGZJSOXBWP', 'PVADT62JUM', 'UBO5EZ7IIH', 'HSOCXZDCZM', 'LIPRETG9WY', 'YNESMGNGWK', 'EAGGQIYQYT', 'A0K1FZANZN', 'OTUYARXZX2', '55KMBQR3HH', 'PRG54RZY7X', 'WHUETYQCMK', '9IA0YLPHU2'}
# UserKeys in user_df not in keystrokes: {'5CECBJXGB3', 'QSFGD1TSPA', '1WMVCCU4RH', 'K4TGUFAPJ8', '0WTDIGPSBZ', '3LBXTMXULC', 'YWAWVFZZZE', 'YFZEXV85OS', 'NTWSB0ULD7', 'KCHR1NSQZO'}

# %%
#Unifying each key here, making sure everything is consistent
keystrokes_df['UserKey'] = keystrokes_df['UserKey'].str.split("_").str[0].str.strip().str.upper()
user_df['UserKey'] = user_df['UserKey'].str.strip().str.upper()

# %%
#Concatenate both files to have a unified pf
merged_df = keystrokes_df.merge(user_df, on="UserKey", how="left")
merged_df
# Out:
#             UserKey    Date     Timestamp Hand HoldTime Direction LatencyTime  \
# 0        0EA27ICBLF  160722  18:41:04.336    L   0101.6        LL      0234.4
# 1        0EA27ICBLF  160722  18:42:14.070    L   0085.9        LL      0437.5
# 2        0EA27ICBLF  160722  18:42:14.273    L   0078.1        LL      0210.9
# 3        0EA27ICBLF  160722  18:42:14.617    L   0062.5        LL      0359.4
# 4        0EA27ICBLF  160722  18:42:15.586    S   0125.0        LS      0187.5
# ...             ...     ...           ...  ...      ...       ...         ...
# 9316853  ZYWLN4JVLA  170126  13:56:20.117    L   0195.3        RL      0425.8
# 9316854  ZYWLN4JVLA  170126  13:56:20.242    R   0105.5        LR      0214.8
# 9316855  ZYWLN4JVLA  170126  13:56:33.625    L   0168.0        LL      0332.0
# 9316856  ZYWLN4JVLA  170126  13:56:33.836    L   0097.7        LL      0281.3
# 9316857  ZYWLN4JVLA  170126  13:56:34.066    L   0168.0        LL      0160.2
#
#         FlightTime             Filename BirthYear  ... Parkinsons Tremors  \
# 0           0156.3  0EA27ICBLF_1607.txt      1952  ...       True    True
# 1           0359.4  0EA27ICBLF_1607.txt      1952  ...       True    True
# 2           0125.0  0EA27ICBLF_1607.txt      1952  ...       True    True
# 3           0281.3  0EA27ICBLF_1607.txt      1952  ...       True    True
# 4           0093.8  0EA27ICBLF_1607.txt      1952  ...       True    True
# ...            ...                  ...       ...  ...        ...     ...
# 9316853      261.7  ZYWLN4JVLA_1701.txt            ...       True   False
# 9316854       19.5  ZYWLN4JVLA_1701.txt            ...       True   False
# 9316855       15.6  ZYWLN4JVLA_1701.txt            ...       True   False
# 9316856      113.3  ZYWLN4JVLA_1701.txt            ...       True   False
# 9316857       62.5  ZYWLN4JVLA_1701.txt            ...       True   False
#
#         DiagnosisYear  Sided       UPDRS  Impact Levadopa    DA   MAOB  Other
# 0                2000   Left  Don't know  Severe     True  True  False  False
# 1                2000   Left  Don't know  Severe     True  True  False  False
# 2                2000   Left  Don't know  Severe     True  True  False  False
# 3                2000   Left  Don't know  Severe     True  True  False  False
# 4                2000   Left  Don't know  Severe     True  True  False  False
# ...               ...    ...         ...     ...      ...   ...    ...    ...
# 9316853                Right  Don't know  Medium     True  True   True   True
# 9316854                Right  Don't know  Medium     True  True   True   True
# 9316855                Right  Don't know  Medium     True  True   True   True
# 9316856                Right  Don't know  Medium     True  True   True   True
# 9316857                Right  Don't know  Medium     True  True   True   True
#
# [9316858 rows x 21 columns]

# %%
#Something is off about dataset above --> Double check

#Parse user info 

#Merge both together and perform ML stuff (hopefullly they have similar parameters -- rows , columns and stuff)

# %%
merged_df["Parkinsons"].value_counts()
# Out:
# Parkinsons
# True     6470722
# False    2544149
# Name: count, dtype: int64

# %%
#Exporting the df file to a file directory for preprocessong

merged_df.to_csv("typing.csv")
