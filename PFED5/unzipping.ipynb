# %%
import pandas as pd
import zipfile

# %%
#Extracting and unzipping dataset 
with zipfile.ZipFile("/users/imbahndu/Desktop/Columbia DBM/PFED5/Preprocessed_data.zip", "r") as zipfile:
    zipfile.extractall()

# %%
#Extracting the frames and heatmaps dataset
with zipfile.ZipFile("/users/imbahndu/Desktop/Columbia DBM/PFED5/frames.zip", "r") as frames:
    frames.extractall()

with zipfile.ZipFile("/users/imbahndu/Desktop/Columbia DBM/PFED5/heatmaps.zip", "r") as heatmaps:
    heatmaps.extractall()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 #Extracting the frames and heatmaps dataset
# ----> 2 with zipfile.ZipFile("/users/imbahndu/Desktop/Columbia DBM/PFED5/frames.zip", "r") as frames:
#       3     frames.extractall()
#       5 with zipfile.ZipFile("/users/imbahndu/Desktop/Columbia DBM/PFED5/heatmaps.zip", "r") as heatmaps:
#
# AttributeError: 'ZipFile' object has no attribute 'ZipFile'
